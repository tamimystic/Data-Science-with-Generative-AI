# %% [markdown]
# # Common Functions/Methods
#  1. len
#  2. max
#  3. min
#  4. sorted <br>
#
#  https://www.w3schools.com/python/python_ref_string.asp

# %%
s="tamim Hossain"

# %%
len(s)
# Out:
# 13

# %%
max(s)
# Out:
# 't'

# %%
sorted(s)
# Out:
# [' ', 'H', 'a', 'a', 'i', 'i', 'm', 'm', 'n', 'o', 's', 's', 't']

# %%
sorted(s,reverse=1)
# Out:
# ['t', 's', 's', 'o', 'n', 'm', 'm', 'i', 'i', 'a', 'a', 'H', ' ']

# %% [markdown]
# * Capitalize
# * Title
# * Upper
# * Lower
# * Swapcase

# %%
s.capitalize()
# Out:
# 'Tamim hossain'

# %%
print(s)
# Out:
# tamim Hossain

# %%
s.title() #every word first character will be Capitalize
# Out:
# 'Tamim Hossain'

# %%
s.upper()
# Out:
# 'TAMIM HOSSAIN'

# %%
s.lower()
# Out:
# 'tamim hossain'

# %%
s="TamiM HossaiN"

# %%
s.swapcase() # upper will be lower and lower will be upper
# Out:
# 'tAMIm hOSSAIn'

# %%
s.count("s")
# Out:
# 2

# %%
s.find("M")
# Out:
# 4

# %%
s.find("x") #here output -1 means ''can not found
# Out:
# -1

# %% [markdown]
# * start with
# * end with

# %%
s.startswith("T")
# Out:
# True

# %%
s.startswith("Ta")
# Out:
# True

# %%
s.startswith("t")
# Out:
# False

# %%
s.endswith("Ta")
# Out:
# False

# %%
s.endswith("iN")
# Out:
# True

# %% [markdown]
# ### Format

# %%
name="tamim"
id=223311232

s="My name is {} and my id is {}"

# %%
s.format(name,id)
# Out:
# 'My name is tamim and my id is 223311232'

# %%
"My name is {} and my id is {}".format(name,id)
# Out:
# 'My name is tamim and my id is 223311232'

# %%
"My name is {1} and my id is {0}".format(name,id) #change format() index number
# Out:
# 'My name is 223311232 and my id is tamim'

# %%
"My name is {1} and my id is {0}".format(id,name) #change format() index number
# Out:
# 'My name is tamim and my id is 223311232'

# %% [markdown]
# ### f string

# %%
f"My name is {name} and my id is {id}"
# Out:
# 'My name is tamim and my id is 223311232'

# %%
age=23
f"My name is {name} and my id is {id}. i am {age} years old"
# Out:
# 'My name is tamim and my id is 223311232. i am 23 years old'

# %% [markdown]
# ### isalnum

# %%
s="Tamim123"

# %%
s.isalnum()
# Out:
# True

# %%
s="1234"
s.isalpha()
# Out:
# False

# %%
s="123"
s.isdigit()
# Out:
# True

# %%
s="name_age"
s.isidentifier()
# Out:
# True

# %% [markdown]
# ### split <br>
# how to different word, or sentence os something

# %%
s="my name is, tamim"
s.split()
# Out:
# ['my', 'name', 'is,', 'tamim']

# %%
s.split(",")
# Out:
# ['my name is', ' tamim']

# %%
s="sdhfiud@hofdhodsh@hhdfsd@"
s.split("@")
# Out:
# ['sdhfiud', 'hofdhodsh', 'hhdfsd', '']

# %% [markdown]
# ## join
# split er oposite

# %%
work=["my", "name", "is", "tamim"]

# %%
s=" "
s=s.join(work)
s
# Out:
# 'my name is tamim'

# %% [markdown]
# * Replace
# * Strip

# %%
s="My name is tamim"

# %%
s.replace("tamim", "alex")
# Out:
# 'My name is alex'

# %%
s # string im-mutable
# Out:
# 'My name is tamim'

# %%
s="my name is tamim               " #remove extra space (only 1st and last)
s.strip()
# Out:
# 'my name is tamim'

# %%
s="                      my name is tamim" #remove extra space (only 1st and last)
s.strip()
# Out:
# 'my name is tamim'

# %%
s="my name is                   tamim" #remove extra space (only 1st and last, but not in middle)
s.strip()
# Out:
# 'my name is                   tamim'
