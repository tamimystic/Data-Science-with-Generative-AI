# %% [markdown]
# <a href="https://colab.research.google.com/github/tamimystic/Data-Science-with-Generative-AI/blob/main/Day_2_Conditional_statements%2Cpip%2C_modules_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ****Today Agenda****
# 1. Condition statement in python <br>
# 2. conditional statement exercises
# 3. modules in python
# 4. pip in python
# 5. how to commit out code to github
# 6. assignment

# %% [markdown]
# # **1. Condition statement in python**

# %%
"""
actual credintials:
email: abc@gmail.com
password: 12345
"""
# Out:
# '\nactual credintials:\nemail: abc@gmail.com\npassword: 12345\n'

# %%
email=input("Enter your email: ")
password=input("Enter your password: ")

actual_email="abc@gmail.com"
actual_password="12345"

if email==actual_email and password==actual_password:
    print("wellcome")
else:
  print("invalid")
# Out:
# invalid

# %%
email=input("Enter your email: ")
password=input("Enter your password: ")

actual_email="abc@gmail.com"
actual_password="12345"

if email==actual_email and password==actual_password:
    print("wellcome")
else:
  print("invalid")
# Out:
# wellcome

# %% [markdown]
# Nested if-else (Condition)

# %%
#use else if (elif)
email=input("Enter your email: ")
password=input("Enter your password: ")

actual_email="abc@gmail.com"
actual_password="12345"

if email==actual_email and password!=actual_password:
    print("Email is right but password wrong")
    email=input("Enter your pass again: ")
    if password==actual_password:
        print("Wellcome")
    else:
        print("invalid")
elif email!=actual_email and password==actual_password:
    print("Password is right but emial wrong")
elif email==actual_email and password==actual_password:
    print("Both are")
else:
  print("Both are wrong")
# Out:
# Email is right but password wrong
# invalid

# %% [markdown]
# *Exercise*

# %% [markdown]
# 1. Find the minimum number from 3 given number

# %%
num1=int(input("Enter your first number: "))
num2=int(input("Enter your second number: "))
num3=int(input("Enter your third number: "))

if(num1<num2 and num1<num3):
  print(num1, "is smallest number")
elif(num2<num1 and num2<num3):
  print(num2, "is smallest number")
else:
  print(num3, "is smallest number")
# Out:
# 3 is smallest number

# %% [markdown]
# 2. Try to build ATM machine <br>
#   ->1. Change pin<br>
#   ->2. Check balance <br>
#   ->3. Withdraw <br>
#   ->4. Deposit <br>
#   ->5. Exit <br>

# %%
menu=input("""
Wellcome to ATM machine

1.Change pin
2. Check balance
3. Withdraw
4. Deposit
5. Exit
""")

if(menu=="1"):
  print("Change pin")
elif(menu=="2"):
  print("Check balance")
elif(menu=="3"):
  print("Withdraw")
elif(menu=="4"):
  print("Deposit")
else:
  print("Exit")
# Out:
# Check balance

# %% [markdown]
# # **Modules in Python** <br>
# *In one line, Module in Pre-define code* <br>
# 1. Buildin Module/Package <br>
# 2. External Module/Package <br>
#
# https://docs.python.org/3/py-modindex.html

# %% [markdown]
# **1. Buildin Module/Package** <br>
#
# ->Internal modules are local to a project or workspace, often used for sharing code within a monorepo <br> ->Think of an internal module like a shared document in a company's internal network. It's available only to employees of that company and is used for company-specific tasks <br> <br>
#     math <br>
#     keywords <br>
#     random <br>
#     datetime <br>

# %% [markdown]
# 1.math

# %%
import math

# %%
math.cos(45)
# Out:
# 0.5253219888177297

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.factorial(5)
# Out:
# 120

# %% [markdown]
# 2. keywords

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(keyword.iskeyword("import"))
# Out:
# True

# %%
print(keyword.iskeyword("imports"))
# Out:
# False

# %% [markdown]
# 3. random

# %%
import random

# %%
random.randint(1,100)
# Out:
# 39

# %% [markdown]
# 4. date-time

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 11, 5, 21, 48, 33, 218816)

# %% [markdown]
# **2. External Module/Package** <br>
# -> External modules are independent packages from a third-party or remote source that must be installed to be used. <br>
# ->Think of an external module like a widely used public software library, like a word processor or a spreadsheet program, that anyone can download and use in their work <br>
#
# https://pypi.org/

# %%
! pip install fastapi
# Out:
# Requirement already satisfied: fastapi in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (0.121.0)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from fastapi) (0.49.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from fastapi) (2.12.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from fastapi) (0.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from starlette<0.50.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tamimystic\.conda\envs\basicpython\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi) (1.3.1)

# %%
from typing import Union

# %%
from fastapi import FastAPI

# %%
app=FastAPI()

# %%
@app.get("/")
def read_root():
    return {"Hello": "World"}

# %%
if __name__=="__main__":
    import uvicorn
    uvicorn.run("main:app",host="127.0.0.1",port=8000,reload=True)
# Out:
# INFO:     Will watch for changes in these directories: ['c:\\Inception BD\\Data-Science-with-Generative-AI\\Basic Python']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [11100] using StatReload
# INFO:     Stopping reloader process [11100]

# %%
# !uvicorn main:app --reload
# Out:
# ^C

# %% [markdown]
# # We can download package/module/library using pip/!pip command <br>
# pip install fastapi
