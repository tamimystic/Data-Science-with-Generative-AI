# %% [markdown]
# # File Handling using Context Manager (with)
#
# ## Using Context Manager (with)
#
# - It's a good idea to close a file after usage as it will free up the resources
# - If we don't close it, garbage collector would close it
# - `with` keyword closes the file as soon as the usage is over

# %% [markdown]
# ## Write

# %%
with open("C:\Inception BD\Data-Science-with-Generative-AI\Python\day9 File handaling, Exception handling, Logging in Python\File handling\demo1.txt","a") as f:
    f.writelines("\nadvance data write")

# %% [markdown]
# ## Read

# %%
with open("C:\Inception BD\Data-Science-with-Generative-AI\Python\day9 File handaling, Exception handling, Logging in Python\File handling\demo1.txt","r") as f:
    s=f.readline()
    print(s)
# Out:
# hello

# %%
with open("C:\Inception BD\Data-Science-with-Generative-AI\Python\day9 File handaling, Exception handling, Logging in Python\File handling\demo1.txt","r") as f:
    while True:
        s=f.readline()
        if s=="":
            break
        else:
            print(s)
# Out:
# hello
#
# hi
#
# how are you?
#
# i am fine
#
# advance data write

# %%
with open("C:\Inception BD\Data-Science-with-Generative-AI\Python\day9 File handaling, Exception handling, Logging in Python\File handling\demo1.txt","r") as f:
    s=f.read()
    print(s)
# Out:
# hello
# hi
# how are you?
# i am fine
# advance data write

# %% [markdown]
# seek() function, cursor selector, from where i want to start it
