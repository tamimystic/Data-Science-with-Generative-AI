# %% [markdown]
# There are 2 stages where error may happen in a program:
#
# - During compilation → **Syntax Error**
# - During execution → **Exceptions**
#
# ---
#
# ## Syntax Error
#
# - Something in the program is not written according to the program grammar.
# - Error is raised by the interpreter/compiler
# - You can solve it by rectifying the program

# %%
# synatx error, this is not run
# print"hello world"

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## Other examples of syntax error
#
# - Leaving symbols like colon, brackets
# - Misspelling a keyword
# - Incorrect indentation
# - Empty if / else / loops / class / functions
# ---

# %% [markdown]
# ## Exceptions
#
# If things go wrong during the execution of the program (runtime), it generally happens when something unforeseen has happened.
#
# - Exceptions are raised by Python runtime
# - You have to tackle it on the fly
#
# ---
#
# ## Examples
#
# - Memory overflow
# - Divide by 0 → logical error
# - Database error

# %%
def div(num):
    r=12/num
    print(num)

# %%
div(8)
# Out:
# 8

# %%
div(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 div(0)
#
# Cell In[5], line 2, in div(num)
#       1 def div(num):
# ----> 2     r=12/num
#       3     print(num)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### use try except block

# %%
# with open("demo1.txt","r") as f:      -> this is now run, bcz it is nopt available

with open("C:\Inception BD\Data-Science-with-Generative-AI\Python\day9 File handaling, Exception handling, Logging in Python\File handling\String data\demo1.txt","r") as f:
    s=f.read()
    print(s)
# Out:
# hello
# hi
# how are you?
# i am fine
# advance data write

# %%
try:
    with open("demo1.txt","r") as f:
        s=f.read()
        print(s)
except:
    print("file not found, creat it first")
# Out:
# file not found, creat it first

# %% [markdown]
# ## Different types of Exception handling

# %% [markdown]
# here a+b is right and here show its output, then compiler say file not found, but this is not right way

# %%
try:
    a=4
    b=5
    print(a+b)
    
    '''with open("demo1.txt","r") as f:
        s=f.read()
        print(s)'''

    '''c=7
    d=8
    print(c+h)'''

    l=[23,345,23,6,3,56]
    l[100]
except FileNotFoundError:
    print("file not found, creat it first")
except NameError:
    print("variable name error")
except IndexError:
    print("Index out of range")
# Out:
# 9
# Index out of range

# %% [markdown]
# we do not write multiple line for error

# %%
try:
    a=4
    b=5
    print(a+b)
    
    with open("demo1.txt","r") as f:
        s=f.read()
        print(s)

    c=7
    d=8
    print(c+h)

    l=[23,345,23,6,3,56]
    l[100]
except Exception as e:
    print(e)
# Out:
# 9
# [Errno 2] No such file or directory: 'demo1.txt'

# %% [markdown]
# ## Raise Exception
#
# - if we need break this code

# %%
raise Exception("hello, this is an error")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 raise Exception("hello, this is an error")
#
# Exception: hello, this is an error

# %%
raise NameError("this is name error")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 raise NameError("this is name error")
#
# NameError: this is name error

# %%
def divide(a,b):
    if b==0:
        raise Exception("can not divide by zero")
    else:
        return a/b
divide(3,0)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[26], line 6
#       4     else:
#       5         return a/b
# ----> 6 divide(3,0)
#
# Cell In[26], line 3, in divide(a, b)
#       1 def divide(a,b):
#       2     if b==0:
# ----> 3         raise Exception("can not divide by zero")
#       4     else:
#       5         return a/b
#
# Exception: can not divide by zero
