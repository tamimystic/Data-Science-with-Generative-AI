# %% [markdown]
# ### tupple method

# %%
t=(1,2,3,4,5,6)

# %%
print(max(t))
print(min(t))
print(sum(t))
print(sorted(t))
# Out:
# 6
# 1
# 21
# [1, 2, 3, 4, 5, 6]

# %%
t.count(4)
# Out:
# 1

# %%
tuppleToList=list(t)
tuppleToList
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
type(tuppleToList)
# Out:
# list

# %% [markdown]
# difference betwen list and tupple
# * syntax
# * mutability
# * speed
# * memory
# * built in functionality
# * error
# * usability

# %%
# memory size difference
import sys
l=list(range(1000))
t=tuple(range(1000))
print(sys.getsizeof(l))
print(sys.getsizeof(t))
# Out:
# 8056
# 8040

# %%
a=[1,2,3]
b=a # that means a and b memory location same

a.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
print(id(a))
print(id(b))
# Out:
# 2958791118912
# 2958791118912

# %%
b=a.copy()
print(id(a))
print(id(b))
# Out:
# 2958791118912
# 2958791095872

# %%
a=(1,2,3)
b=a

a=a+(4,)
print(a)
print(b)
# Out:
# (1, 2, 3, 4)
# (1, 2, 3)

# %%
(a,b,c)=(1,2,3)

# %%
print((a,b,c))
# Out:
# (1, 2, 3)

# %%
[a,b,c]=[1,2,3]
print([a,b,c])
# Out:
# [1, 2, 3]

# %%
(a,b,*others)=(1,2,3,4,5,7,6,8)

# %%
print(a,b)
# Out:
# 1 2

# %%
others # here others is list
# Out:
# [3, 4, 5, 7, 6, 8]

# %%
f=tuple(others)
f
# Out:
# (3, 4, 5, 7, 6, 8)

# %%
a=(1,2,3,4,5)
b=(6,7,8,9,10)
zip(a,b)

# %%
tuple(zip(a,b))
# Out:
# ((1, 6), (2, 7), (3, 8), (4, 9), (5, 10))
