# %%
s1={1,2,3}

# %%
# s1[0]

# %% [markdown]
# adding items

# %%
s={1,2,3,4}
s.add(6)

# %%
s
# Out:
# {1, 2, 3, 4, 6}

# %%
s.update([11,12,13,12])
s
# Out:
# {1, 2, 3, 4, 6, 11, 12, 13}

# %% [markdown]
# delete (discard,remove,pop,clear)

# %%
s.discard(11)
s
# Out:
# {1, 2, 3, 4, 6, 12, 13}

# %%
s.remove(12)
s
# Out:
# {1, 2, 3, 4, 6, 13}

# %%
s.pop()
s
# Out:
# {2, 3, 4, 6, 13}

# %%
s.clear()
s
# Out:
# set()
