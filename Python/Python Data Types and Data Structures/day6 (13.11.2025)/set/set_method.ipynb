# %% [markdown]
# min, max, sorted, all same like tuple and list

# %%
s1={1,2,3,4}
s2={3,4,5,6,7,8}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.intersection(s2)
# Out:
# {3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.intersection_update(s2)

# %%
print(s1)
print(s2)
# Out:
# {3, 4}
# {3, 4, 5, 6, 7, 8}

# %%
s1={1,2,3,4}
s2={3,4,5,6,7,8}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 5, 6, 7, 8}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.symmetric_difference_update(s2)

# %%
print(s1)
print(s2)
# Out:
# {1, 2, 5, 6, 7, 8}
# {3, 4, 5, 6, 7, 8}
