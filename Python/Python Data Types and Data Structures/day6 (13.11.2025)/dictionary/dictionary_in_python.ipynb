# %% [markdown]
# A Python dictionary is a built-in data type that stores data in key-value pairs. It is an ordered, changeable, and efficient collection type <br>
# Key Characteristics: <br>
# Key-Value Pairs: Each item in a dictionary consists of a key and its corresponding value, separated by a colon (:).<br>
# Ordered (Python 3.7+): Dictionaries maintain the insertion order of their items.<br>
# Changeable: You can add, remove, or modify items in a dictionary after it's created.<br>
# No Duplicate Keys: Each key within a dictionary must be unique. If a key is repeated, the last assigned value for that key will be stored.<br>
# Immutable Keys: Dictionary keys must be immutable data types, such as strings, numbers, or tuples. Lists and other dictionaries cannot be used as keys.<br>
# Mutable Values: Dictionary values can be of any data type, including other collections like lists or dictionaries.<br>

# %%
my_dict = {"name": "Alice", "age": 30, "city": "New York"}

# %%
my_dict
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
my_dict["name"]
# Out:
# 'Alice'

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

# %%
thisdict
# Out:
# {'brand': 'Ford',
#  'electric': False,
#  'year': 1964,
#  'colors': ['red', 'white', 'blue']}

# %% [markdown]
# change items

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["color"] = "red"
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"color": "red"})

# %% [markdown]
# remove key-value pair

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.clear()
print(thisdict)
# Out:
# {}

# %% [markdown]
# Loops in dict

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
for x in thisdict:
  print(x)
# Out:
# brand
# model
# year

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

# %%
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}

# %%
print(myfamily["child2"]["name"])
# Out:
# Tobias

# %%
for x, obj in myfamily.items():
  print(x)

  for y in obj:
    print(y + ':', obj[y])
# Out:
# child1
# name: Emil
# year: 2004
# child2
# name: Tobias
# year: 2007
# child3
# name: Linus
# year: 2011

# %% [markdown]
# Method	Description
# clear()	Removes all the elements from the dictionary
# copy()	Returns a copy of the dictionary
# fromkeys()	Returns a dictionary with the specified keys and value
# get()	Returns the value of the specified key
# items()	Returns a list containing a tuple for each key value pair
# keys()	Returns a list containing the dictionary's keys
# pop()	Removes the element with the specified key
# popitem()	Removes the last inserted key-value pair
# setdefault()	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
# update()	Updates the dictionary with the specified key-value pairs
# values()	Returns a list of all the values in the dictionary
