# %%
s1={1,2,3,4,5}
s2={4,5,6,7,8}

# %% [markdown]
# Union

# %% [markdown]
# intercetion

# %%
s1 & s2
# Out:
# {4, 5}

# %%
# symentric difference
s1^s2
# Out:
# {1, 2, 3, 6, 7, 8}

# %% [markdown]
# membership

# %%
1 in s1
# Out:
# True

# %% [markdown]
# iteration

# %%
for i in s1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
