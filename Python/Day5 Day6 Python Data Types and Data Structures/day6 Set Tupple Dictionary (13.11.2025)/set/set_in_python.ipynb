# %% [markdown]
# In Python, a set is an unordered collection of unique and immutable elements. Sets are a fundamental data structure, similar to lists and tuples, but with distinct characteristics
# * Unordered
# * Unique Elements
# * Mutable (the set itself)
# * Immutable Elements  (within the set)

# %% [markdown]
# ### creating set

# %%
s={1,2,3,5}
print(s)
type(s)
# Out:
# {1, 2, 3, 5}
# set

# %%
s1={1,2,3,4,(5,6)} # s1={1,2,3,4,{5,6}} this is not right

# %%
s1
# Out:
# {(5, 6), 1, 2, 3, 4}

# %%
s1={1,2,3,4,5}
s2={3,2,4,1,5}

s1==s2
# Out:
# True

# %%
s2={1,True,'hello'}

# %%
s2
# Out:
# {1, 'hello'}

# %%
s3={1,2,2,3,3,4,4,4}
s3
# Out:
# {1, 2, 3, 4}
